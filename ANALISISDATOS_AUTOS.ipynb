# %% [markdown]
# <img SRC="img01.png"/>
# <center><h1 Style="color:#DC143C">Analisis de Datos</h1></center>
# <center><h5>Universidad Catro Carazo</h5></center>
# </br>
# <center><h6>2C - 2022</h6></center>
# </br>
# </br>
# <p Style="text-aling: justify">El carro de la presente imagen, es un carro antiguo de los años 70 y 80 s. </p>
# <a  href="https://archive.ics.uci.edu/ml/index.php">Fuente de datos para el analisis</a>

# %% [markdown]
# <h2 Style="color:#DC143C"> 1.Carga y estandarizacion de los set de datos</h2>
# <p> Que se hace en esta etapa?</p>
#
# <o1>
#
#     <1i>Importar las librerias necesarias</1i>
#     <1i>Importar el o los set de datos </1i>
#     <1i>Revisar los encabezados de los dataframes</1i>
#
#
# </o1>
# <h3 style="color:#DC143C">1.1. Importar las librerias </h3>

# %%
import pandas as pd                 #se usa para el manejo de datafrom 
import numpy as np                  #se usa para el manejo de estructura de datos 
import matplotlib.pyplot as ptl     #se usa para el manejo de graficos

# %% [markdown]
# <h3 Style ="color:#DC143C">1.2. Importar el set de datos </h3>

# %%
cols = ["symboling", "normalized", "make", "fuel", "aspiration", "doors",
"style", "wheels", "engine", "base", "length", "width", "heingt",
"curb", "engineType", "Cylinders", "engine-size", "system", "bore", "stroke",
"compression", "horsepower", "peak", "City", "Higway", "price"]

df_1er_autos= pd.read_csv("autos.csv", names=cols)
df_2do_autos = pd.read_csv("Autos.csv", names=cols)

# %%
df_1er_autos
df_2do_autos
# Out:
#     symboling normalized        make    fuel aspiration doors        style  \
# 0           2        134      toyota     gas        std   two      hardtop
# 1           2        134      toyota     gas        std   two    hatchback
# 2           2        134      toyota     gas        std   two      hardtop
# 3           2        134      toyota     gas        std   two    hatchback
# 4           2        134      toyota     gas        std   two  convertible
# 5          -1         65      toyota     gas        std  four        sedan
# 6          -1         65      toyota  diesel      turbo  four        sedan
# 7          -1         65      toyota     gas        std  four    hatchback
# 8          -1         65      toyota     gas        std  four        sedan
# 9          -1         65      toyota     gas        std  four    hatchback
# 10          3        197      toyota     gas        std   two    hatchback
# ...

# %%
df_1er_autos.shape #esto me permite conocer el tamaño del DataFrame
# Out:
# (29, 26)

# %%
df_2do_autos.shape
# Out:
# (29, 26)

# %%
df_1er_autos.head(10)  #10 significa la cantidad de filas que quiero analizar, si quiero no le pongo cantidad por lo tanto quito parentesis o si quiero pongo la cantidad
# Out:
#    symboling normalized    make    fuel aspiration doors        style wheels  \
# 0          2        134  toyota     gas        std   two      hardtop    rwd
# 1          2        134  toyota     gas        std   two    hatchback    rwd
# 2          2        134  toyota     gas        std   two      hardtop    rwd
# 3          2        134  toyota     gas        std   two    hatchback    rwd
# 4          2        134  toyota     gas        std   two  convertible    rwd
# 5         -1         65  toyota     gas        std  four        sedan    fwd
# 6         -1         65  toyota  diesel      turbo  four        sedan    fwd
# 7         -1         65  toyota     gas        std  four    hatchback    fwd
# 8         -1         65  toyota     gas        std  four        sedan    fwd
# 9         -1         65  toyota     gas        std  four    hatchback    fwd
#
#   engine   base  ...  engine-size  system  bore  stroke compression  \
# ...

# %%
df_1er_autos.tail(10) #tail es cola osea que va a seleccionar las ultimas lineas con head que es cabeza selecciona las primeras lineas
# Out:
#     symboling normalized        make    fuel aspiration doors        style  \
# 19          2         94  volkswagen  diesel      turbo  four        sedan
# 20          2         94  volkswagen     gas        std  four        sedan
# 21          3          ?  volkswagen     gas        std   two  convertible
# 22          3        256  volkswagen     gas        std   two    hatchback
# 23          0          ?  volkswagen     gas        std  four        sedan
# 24          0          ?  volkswagen  diesel      turbo  four        sedan
# 25          0          ?  volkswagen     gas        std  four        wagon
# 26         -2        103       volvo     gas        std  four        sedan
# 27         -1         74       volvo     gas        std  four        wagon
# 28         -2        103       volvo     gas        std  four        sedan
#
#    wheels engine   base  ...  engine-size  system  bore  stroke compression  \
# ...

# %%
df_1er_autos.describe() # esta funcion describe los valores estadisticamente
# Out:
#        symboling        base      length      width     heingt         curb  \
# count  29.000000   29.000000   29.000000  29.000000  29.000000    29.000000
# mean    0.827586  100.103448  177.186207  66.134483  54.406897  2580.000000
# std     1.691765    3.082726    7.178327   0.917012   1.666676   310.887325
# min    -2.000000   94.500000  159.300000  64.000000  51.400000  2209.000000
# 25%    -1.000000   97.300000  171.700000  65.500000  53.000000  2300.000000
# 50%     2.000000  100.400000  176.200000  66.500000  54.900000  2536.000000
# 75%     2.000000  102.400000  183.100000  66.900000  55.700000  2912.000000
# max     3.000000  104.500000  188.800000  67.700000  57.500000  3151.000000
#
#        engine-size       bore     stroke  compression  horsepower  \
# count    29.000000  29.000000  29.000000    29.000000   29.000000
# mean    128.000000   3.330690   3.402069    11.475862  102.413793
# std      23.653752   0.240088   0.108278     5.318610   29.382353
# ...

# %% [markdown]
# <h3 Style ="color:#DC143C">1.3. Revisar encabezados de los set de datos </h3>

# %%
df_1er_autos.info () #informacion especifica de una columna
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 26 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   symboling    29 non-null     int64
#  1   normalized   29 non-null     object
#  2   make         29 non-null     object
#  3   fuel         29 non-null     object
#  4   aspiration   29 non-null     object
#  5   doors        29 non-null     object
#  6   style        29 non-null     object
#  7   wheels       29 non-null     object
#  8   engine       29 non-null     object
#  9   base         29 non-null     float64
#  10  length       29 non-null     float64
#  11  width        29 non-null     float64
#  12  heingt       29 non-null     float64
#  13  curb         29 non-null     int64
#  14  engineType   29 non-null     object
#  15  Cylinders    29 non-null     object
#  16  engine-size  29 non-null     int64
#  17  system       29 non-null     object
# ...

# %%
df_1er_autos.columns #solo para ver las columnas y no todo el archivo
# Out:
# Index(['symboling', 'normalized', 'make', 'fuel', 'aspiration', 'doors',
#        'style', 'wheels', 'engine', 'base', 'length', 'width', 'heingt',
#        'curb', 'engineType', 'Cylinders', 'engine-size', 'system', 'bore',
#        'stroke', 'compression', 'horsepower', 'peak', 'City', 'Higway',
#        'price'],
#       dtype='object')

# %%
df_2do_autos.columns
# Out:
# Index(['symboling', 'normalized', 'make', 'fuel', 'aspiration', 'doors',
#        'style', 'wheels', 'engine', 'base', 'length', 'width', 'heingt',
#        'curb', 'engineType', 'Cylinders', 'engine-size', 'system', 'bore',
#        'stroke', 'compression', 'horsepower', 'peak', 'City', 'Higway',
#        'price'],
#       dtype='object')

# %% [markdown]
# #INICIA LA SEGUNDA SEMANA

# %% [markdown]
# <h3 Style="color:#8B008B">1.4 Unir archivos en un solo DataFrame</h3>

# %%
unionArchivos = [df_1er_autos, df_2do_autos] #lista de DataFrame
dfAutos = pd.concat(unionArchivos)
dfAutos.shape #en el parentesis de abajo el primer dato es la cantidad de registros y el segundo cantidad de archivos
# Out:
# (58, 26)

# %%
dfAutos.head(3)
# Out:
#    symboling normalized    make fuel aspiration doors      style wheels  \
# 0          2        134  toyota  gas        std   two    hardtop    rwd
# 1          2        134  toyota  gas        std   two  hatchback    rwd
# 2          2        134  toyota  gas        std   two    hardtop    rwd
#
#   engine  base  ...  engine-size  system  bore  stroke compression horsepower  \
# 0  front  98.4  ...          146    mpfi  3.62     3.5         9.3        116
# 1  front  98.4  ...          146    mpfi  3.62     3.5         9.3        116
# 2  front  98.4  ...          146    mpfi  3.62     3.5         9.3        116
#
#    peak City  Higway  price
# 0  4800   24      30   9639
# 1  4800   24      30   9989
# 2  4800   24      30  11199
#
# [3 rows x 26 columns]

# %% [markdown]
# # A CONTINUACION FORMAS PARA SEPARAR FILAS Y COLUMNAS

# %%
dftem=dfAutos.iloc[:,0:10] #el primer espacio : antes de la coma es = a la cantidad de filas, el segundo campo despues de la coma significa la cantidd de columnas que deseo seleccionar

# %%
dftem.head(6) #se usa para cortar columnas , depende la version de python se usa loc o iloc para las mas recientes, este proceso se usa para separar columnas
# Out:
#    symboling normalized    make fuel aspiration doors        style wheels  \
# 0          2        134  toyota  gas        std   two      hardtop    rwd
# 1          2        134  toyota  gas        std   two    hatchback    rwd
# 2          2        134  toyota  gas        std   two      hardtop    rwd
# 3          2        134  toyota  gas        std   two    hatchback    rwd
# 4          2        134  toyota  gas        std   two  convertible    rwd
# 5         -1         65  toyota  gas        std  four        sedan    fwd
#
#   engine   base
# 0  front   98.4
# 1  front   98.4
# 2  front   98.4
# 3  front   98.4
# 4  front   98.4
# 5  front  102.4

# %%
dftem=dfAutos.iloc[[0,3,6,24],[0,5,6]]

# %%
dftem
# Out:
#     symboling doors      style
# 0           2   two    hardtop
# 3           2   two  hatchback
# 6          -1  four      sedan
# 24          0  four      sedan

# %% [markdown]
# <h2 Style="color:#DAA520">2. Manejo de valores faltantes o perdidos </h2>
# <p> Que se hace en esta etapa?</p>
#
# <ol>
#     <li>Como se muestran los valores faltantes (null, espacio en blanco o vacio, o un signo de ?) y estandarizarlos (NaN(nom and number))</li>
#     <li>Contar la cantidad de valores de NaN, faltantes por variables (columna) </li>
#     <li>Analisis de imputacion(el promedio / se usa tambien procesos de MACHINE LEARNING) para el caso de los numericos </li>
#     <li>Analisis de imputacion(con el valor mas frecuente de la columna) para el caso de los caracteres </li>
#     <li> Eliminacion de filas y columnas con valores faltantes  </li>
# </ol>
#
# <h3 style="#DAA520">2.1. Identificar como se muestran los valores faltantes y estandarizarlos </h3>

# %%
dfAutos.head(15)
# Out:
#     symboling normalized        make    fuel aspiration doors        style  \
# 0           2        134      toyota     gas        std   two      hardtop
# 1           2        134      toyota     gas        std   two    hatchback
# 2           2        134      toyota     gas        std   two      hardtop
# 3           2        134      toyota     gas        std   two    hatchback
# 4           2        134      toyota     gas        std   two  convertible
# 5          -1         65      toyota     gas        std  four        sedan
# 6          -1         65      toyota  diesel      turbo  four        sedan
# 7          -1         65      toyota     gas        std  four    hatchback
# 8          -1         65      toyota     gas        std  four        sedan
# 9          -1         65      toyota     gas        std  four    hatchback
# 10          3        197      toyota     gas        std   two    hatchback
# ...

# %%
dfAutos.replace("?", np.nan, inplace = True)
dfAutos.head(10)
# Out:
#    symboling normalized    make    fuel aspiration doors        style wheels  \
# 0          2        134  toyota     gas        std   two      hardtop    rwd
# 1          2        134  toyota     gas        std   two    hatchback    rwd
# 2          2        134  toyota     gas        std   two      hardtop    rwd
# 3          2        134  toyota     gas        std   two    hatchback    rwd
# 4          2        134  toyota     gas        std   two  convertible    rwd
# 5         -1         65  toyota     gas        std  four        sedan    fwd
# 6         -1         65  toyota  diesel      turbo  four        sedan    fwd
# 7         -1         65  toyota     gas        std  four    hatchback    fwd
# 8         -1         65  toyota     gas        std  four        sedan    fwd
# 9         -1         65  toyota     gas        std  four    hatchback    fwd
#
#   engine   base  ...  engine-size  system  bore  stroke compression  \
# ...

# %% [markdown]
# <h3 Style="color:#DAA520">2.2 Contar los valores faltantes por columna </h3>

# %%
valoresPerdidos = dfAutos.isnull()

# %%
valoresPerdidos.head(5)
# Out:
#    symboling  normalized   make   fuel  aspiration  doors  style  wheels  \
# 0      False       False  False  False       False  False  False   False
# 1      False       False  False  False       False  False  False   False
# 2      False       False  False  False       False  False  False   False
# 3      False       False  False  False       False  False  False   False
# 4      False       False  False  False       False  False  False   False
#
#    engine   base  ...  engine-size  system   bore  stroke  compression  \
# 0   False  False  ...        False   False  False   False        False
# 1   False  False  ...        False   False  False   False        False
# 2   False  False  ...        False   False  False   False        False
# 3   False  False  ...        False   False  False   False        False
# 4   False  False  ...        False   False  False   False        False
#
#    horsepower   peak   City  Higway  price
# 0       False  False  False   False  False
# ...

# %%
for column in valoresPerdidos.columns.values.tolist():
    print (column)
    print (valoresPerdidos[column].value_counts())
    print ("")
# Out:
# symboling
# False    58
# Name: symboling, dtype: int64
#
# normalized
# False    48
# True     10
# Name: normalized, dtype: int64
#
# make
# False    58
# Name: make, dtype: int64
#
# fuel
# False    58
# Name: fuel, dtype: int64
#
# aspiration
# False    58
# Name: aspiration, dtype: int64
#
# doors
# False    58
# Name: doors, dtype: int64
#
# style
# False    58
# Name: style, dtype: int64
#
# wheels
# False    58
# Name: wheels, dtype: int64
#
# engine
# False    58
# Name: engine, dtype: int64
#
# base
# False    58
# Name: base, dtype: int64
#
# length
# False    58
# Name: length, dtype: int64
#
# width
# False    58
# Name: width, dtype: int64
#
# heingt
# False    58
# Name: heingt, dtype: int64
#
# curb
# False    58
# Name: curb, dtype: int64
#
# engineType
# False    58
# Name: engineType, dtype: int64
#
# Cylinders
# False    58
# Name: Cylinders, dtype: int64
#
# engine-size
# False    58
# Name: engine-size, dtype: int64
#
# system
# False    58
# ...

# %% [markdown]
# <h3 Style="color:#DAA520">2.3 Imputar datos numericos  </h3> #SE AGREGA IMAGEN O PANTALLAZO QUE NECESITAMOS PARA EL ANALISIS CON EL CODIGO DE LA IMAGEN QUE GUARDE EN LA CARPETA DE NUEVO
# <img SRC="EXTRACTO.PNG"/>

# %%
avg_normalized = dfAutos["normalized"].astype("float").mean(axis=0)
print("la media del normalized:", avg_normalized)
# Out:
# la media del normalized: 113.70833333333333

# %%
dfAutos["normalized"].replace(np.nan, 122, inplace=True)
dfAutos.head(3)
# Out:
#    symboling normalized    make fuel aspiration doors      style wheels  \
# 0          2        134  toyota  gas        std   two    hardtop    rwd
# 1          2        134  toyota  gas        std   two  hatchback    rwd
# 2          2        134  toyota  gas        std   two    hardtop    rwd
#
#   engine  base  ...  engine-size  system  bore  stroke compression horsepower  \
# 0  front  98.4  ...          146    mpfi  3.62     3.5         9.3        116
# 1  front  98.4  ...          146    mpfi  3.62     3.5         9.3        116
# 2  front  98.4  ...          146    mpfi  3.62     3.5         9.3        116
#
#    peak City  Higway  price
# 0  4800   24      30   9639
# 1  4800   24      30   9989
# 2  4800   24      30  11199
#
# [3 rows x 26 columns]

# %% [markdown]
# <h3 Style="color:#DAA520">2.4 Imputar datos tipo caracter   </h3>

# %% [markdown]
# <img SRC="img03.png"/>

# %%
dfAutos.head(5)
# Out:
#    symboling normalized    make fuel aspiration doors        style wheels  \
# 0          2        134  toyota  gas        std   two      hardtop    rwd
# 1          2        134  toyota  gas        std   two    hatchback    rwd
# 2          2        134  toyota  gas        std   two      hardtop    rwd
# 3          2        134  toyota  gas        std   two    hatchback    rwd
# 4          2        134  toyota  gas        std   two  convertible    rwd
#
#   engine  base  ...  engine-size  system  bore  stroke compression horsepower  \
# 0  front  98.4  ...          146    mpfi  3.62     3.5         9.3        116
# 1  front  98.4  ...          146    mpfi  3.62     3.5         9.3        116
# 2  front  98.4  ...          146    mpfi  3.62     3.5         9.3        116
# 3  front  98.4  ...          146    mpfi  3.62     3.5         9.3        116
# 4  front  98.4  ...          146    mpfi  3.62     3.5         9.3        116
#
#    peak City  Higway  price
# ...

# %%
dfAutos["doors"].value_counts() #se puede hacer de esta forma mas general , esto para saber cual es el dato mas frecuente que se usa
# Out:
# four    36
# two     22
# Name: doors, dtype: int64

# %%
dfAutos["doors"].value_counts().idxmax() # o se puede hacer de esta otra forma mas especifico
# Out:
# 'four'

# %%
#ahora se va a sustituir los valores e blanco por cuatro porque es el que mas se utiliza con frecuencia

# %%
dfAutos["doors"].replace(np.nan, "four", inplace=True)

# %%
valoresPerdidos=dfAutos.isnull() # se identifica que el numero 226 sea igual en todo el archivo que esta abajo 
for column in valoresPerdidos.columns.values.tolist():
    print (column)
    print (valoresPerdidos[column].value_counts())
    print ("")
# Out:
# symboling
# False    58
# Name: symboling, dtype: int64
#
# normalized
# False    58
# Name: normalized, dtype: int64
#
# make
# False    58
# Name: make, dtype: int64
#
# fuel
# False    58
# Name: fuel, dtype: int64
#
# aspiration
# False    58
# Name: aspiration, dtype: int64
#
# doors
# False    58
# Name: doors, dtype: int64
#
# style
# False    58
# Name: style, dtype: int64
#
# wheels
# False    58
# Name: wheels, dtype: int64
#
# engine
# False    58
# Name: engine, dtype: int64
#
# base
# False    58
# Name: base, dtype: int64
#
# length
# False    58
# Name: length, dtype: int64
#
# width
# False    58
# Name: width, dtype: int64
#
# heingt
# False    58
# Name: heingt, dtype: int64
#
# curb
# False    58
# Name: curb, dtype: int64
#
# engineType
# False    58
# Name: engineType, dtype: int64
#
# Cylinders
# False    58
# Name: Cylinders, dtype: int64
#
# engine-size
# False    58
# Name: engine-size, dtype: int64
#
# system
# False    58
# Name: system, dtype: int64
#
# ...

# %% [markdown]
# <h3 Style="color:#DAA520">2.5 Eliminar filas con valores faltantes  </h3>

# %%
dfAutos.dropna(subset=["price"], axis=0, inplace=True)
dfAutos.reset_index(drop=True, inplace=True) #esto se hace para ver la cantidad de filas ejm 1,2,3,4,5,6... se le llama indice

# %%
dfAutos.dropna(subset=["bore"], axis=0, inplace=True)
dfAutos.reset_index(drop=True, inplace=True)

# %%
dfAutos.dropna(subset=["stroke"], axis=0, inplace=True)
dfAutos.reset_index(drop=True, inplace=True)

# %%
dfAutos.dropna(subset=["horsepower"], axis=0, inplace=True)
dfAutos.reset_index(drop=True, inplace=True)

# %%
dfAutos.dropna(subset=["peak"], axis=0, inplace=True)
dfAutos.reset_index(drop=True, inplace=True)

# %%
dfAutos
# Out:
#     symboling normalized        make    fuel aspiration doors        style  \
# 0           2        134      toyota     gas        std   two      hardtop
# 1           2        134      toyota     gas        std   two    hatchback
# 2           2        134      toyota     gas        std   two      hardtop
# 3           2        134      toyota     gas        std   two    hatchback
# 4           2        134      toyota     gas        std   two  convertible
# 5          -1         65      toyota     gas        std  four        sedan
# 6          -1         65      toyota  diesel      turbo  four        sedan
# 7          -1         65      toyota     gas        std  four    hatchback
# 8          -1         65      toyota     gas        std  four        sedan
# 9          -1         65      toyota     gas        std  four    hatchback
# 10          3        197      toyota     gas        std   two    hatchback
# ...

# %% [markdown]
# <h2 Style="color:#8B008B">3.Estandarizacion de datos </h2>
# <p> Que se hace con esta etapa? </p>
#
# <ol>
#     <li>Verificar el dominio de las variables y se ajusta, si es necesario</li>
#     <li>Convertir valores en funcion de la interpretacion</li>
#     <li>Normalizar los datos para que sus valores queden entre 0 y 1</li>
#     <li>Agrupar datos (Binning)</li>
#
# </ol>
#
# <h3 Style="color:#8B008B">3.1 Verificar el dominio de la variable </h3>

# %%
dfAutos.head(5)
# Out:
#    symboling normalized    make fuel aspiration doors        style wheels  \
# 0          2        134  toyota  gas        std   two      hardtop    rwd
# 1          2        134  toyota  gas        std   two    hatchback    rwd
# 2          2        134  toyota  gas        std   two      hardtop    rwd
# 3          2        134  toyota  gas        std   two    hatchback    rwd
# 4          2        134  toyota  gas        std   two  convertible    rwd
#
#   engine  base  ...  engine-size  system  bore  stroke compression horsepower  \
# 0  front  98.4  ...          146    mpfi  3.62     3.5         9.3        116
# 1  front  98.4  ...          146    mpfi  3.62     3.5         9.3        116
# 2  front  98.4  ...          146    mpfi  3.62     3.5         9.3        116
# 3  front  98.4  ...          146    mpfi  3.62     3.5         9.3        116
# 4  front  98.4  ...          146    mpfi  3.62     3.5         9.3        116
#
#    peak City  Higway  price
# ...

# %%
#arriba en el apartada 2.5 se agregaron variables para eliminar

# %%
dfAutos.dtypes #modificar columnas
# Out:
# symboling        int64
# normalized      object
# make            object
# fuel            object
# aspiration      object
# doors           object
# style           object
# wheels          object
# engine          object
# base           float64
# length         float64
# width          float64
# heingt         float64
# curb             int64
# engineType      object
# Cylinders       object
# engine-size      int64
# system          object
# bore           float64
# stroke         float64
# compression    float64
# horsepower       int64
# peak             int64
# City             int64
# Higway           int64
# price            int64
# dtype: object

# %%
dfAutos["normalized"] = dfAutos["normalized"].astype("int")

# %%
dfAutos.dtypes
# Out:
# symboling        int64
# normalized       int32
# make            object
# fuel            object
# aspiration      object
# doors           object
# style           object
# wheels          object
# engine          object
# base           float64
# length         float64
# width          float64
# heingt         float64
# curb             int64
# engineType      object
# Cylinders       object
# engine-size      int64
# system          object
# bore           float64
# stroke         float64
# compression    float64
# horsepower       int64
# peak             int64
# City             int64
# Higway           int64
# price            int64
# dtype: object

# %%
dfAutos[["normalized", "peak"]]=dfAutos[["normalized", "peak"]].astype("int")
dfAutos[["bore", "stroke", "price"]]=dfAutos[["bore", "stroke", "price"]].astype("float")

# %%
dfAutos.dtypes
# Out:
# symboling        int64
# normalized       int32
# make            object
# fuel            object
# aspiration      object
# doors           object
# style           object
# wheels          object
# engine          object
# base           float64
# length         float64
# width          float64
# heingt         float64
# curb             int64
# engineType      object
# Cylinders       object
# engine-size      int64
# system          object
# bore           float64
# stroke         float64
# compression    float64
# horsepower       int64
# peak             int32
# City             int64
# Higway           int64
# price          float64
# dtype: object

# %% [markdown]
# <h3 Style="color:#8B008B">3.2 Convertir valores en funcion de su interpretacion </h3>

# %%
dfAutos.head(5)
# Out:
#    symboling  normalized    make fuel aspiration doors        style wheels  \
# 0          2         134  toyota  gas        std   two      hardtop    rwd
# 1          2         134  toyota  gas        std   two    hatchback    rwd
# 2          2         134  toyota  gas        std   two      hardtop    rwd
# 3          2         134  toyota  gas        std   two    hatchback    rwd
# 4          2         134  toyota  gas        std   two  convertible    rwd
#
#   engine  base  ...  engine-size  system  bore  stroke compression horsepower  \
# 0  front  98.4  ...          146    mpfi  3.62     3.5         9.3        116
# 1  front  98.4  ...          146    mpfi  3.62     3.5         9.3        116
# 2  front  98.4  ...          146    mpfi  3.62     3.5         9.3        116
# 3  front  98.4  ...          146    mpfi  3.62     3.5         9.3        116
# 4  front  98.4  ...          146    mpfi  3.62     3.5         9.3        116
#
#    peak City  Higway    price
# ...

# %%
dfAutos["city-L/100KM"]=235/dfAutos["City"]
dfAutos.head(5)
# Out:
#    symboling  normalized    make fuel aspiration doors        style wheels  \
# 0          2         134  toyota  gas        std   two      hardtop    rwd
# 1          2         134  toyota  gas        std   two    hatchback    rwd
# 2          2         134  toyota  gas        std   two      hardtop    rwd
# 3          2         134  toyota  gas        std   two    hatchback    rwd
# 4          2         134  toyota  gas        std   two  convertible    rwd
#
#   engine  base  ...  system  bore  stroke  compression horsepower  peak  City  \
# 0  front  98.4  ...    mpfi  3.62     3.5          9.3        116  4800    24
# 1  front  98.4  ...    mpfi  3.62     3.5          9.3        116  4800    24
# 2  front  98.4  ...    mpfi  3.62     3.5          9.3        116  4800    24
# 3  front  98.4  ...    mpfi  3.62     3.5          9.3        116  4800    24
# 4  front  98.4  ...    mpfi  3.62     3.5          9.3        116  4800    24
#
#   Higway    price  city-L/100KM
# ...

# %%
dfAutos["Higway-L/100KM"]=235/dfAutos["Higway"]
dfAutos.head(5)
# Out:
#    symboling  normalized    make fuel aspiration doors        style wheels  \
# 0          2         134  toyota  gas        std   two      hardtop    rwd
# 1          2         134  toyota  gas        std   two    hatchback    rwd
# 2          2         134  toyota  gas        std   two      hardtop    rwd
# 3          2         134  toyota  gas        std   two    hatchback    rwd
# 4          2         134  toyota  gas        std   two  convertible    rwd
#
#   engine  base  ...  bore  stroke  compression  horsepower  peak City  Higway  \
# 0  front  98.4  ...  3.62     3.5          9.3         116  4800   24      30
# 1  front  98.4  ...  3.62     3.5          9.3         116  4800   24      30
# 2  front  98.4  ...  3.62     3.5          9.3         116  4800   24      30
# 3  front  98.4  ...  3.62     3.5          9.3         116  4800   24      30
# 4  front  98.4  ...  3.62     3.5          9.3         116  4800   24      30
#
#      price  city-L/100KM  Higway-L/100KM
# ...

# %% [markdown]
# <h3 Style="color:#8B008B">3.3 Normalizacion de los Datos</h3>

# %%
dfAutos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 28 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   symboling       58 non-null     int64
#  1   normalized      58 non-null     int32
#  2   make            58 non-null     object
#  3   fuel            58 non-null     object
#  4   aspiration      58 non-null     object
#  5   doors           58 non-null     object
#  6   style           58 non-null     object
#  7   wheels          58 non-null     object
#  8   engine          58 non-null     object
#  9   base            58 non-null     float64
#  10  length          58 non-null     float64
#  11  width           58 non-null     float64
#  12  heingt          58 non-null     float64
#  13  curb            58 non-null     int64
#  14  engineType      58 non-null     object
#  15  Cylinders       58 non-null     object
#  16  engine-size     58 non-null     int64
# ...

# %%
dfTemp=dfAutos[["length","width","heingt"]]
dfTemp.head(5)
# Out:
#    length  width  heingt
# 0   176.2   65.6    52.0
# 1   176.2   65.6    52.0
# 2   176.2   65.6    52.0
# 3   176.2   65.6    52.0
# 4   176.2   65.6    53.0

# %%
dfAutos["length"]=dfAutos["length"]/dfAutos["length"].max()
dfAutos["width"]=dfAutos["width"]/dfAutos["width"].max()
dfAutos["heingt"]=dfAutos["heingt"]/dfAutos["heingt"].max()

# %%
dfTemp=dfAutos[["length","width","heingt"]]
dfTemp.head(5)
# Out:
#      length     width    heingt
# 0  0.933263  0.968981  0.904348
# 1  0.933263  0.968981  0.904348
# 2  0.933263  0.968981  0.904348
# 3  0.933263  0.968981  0.904348
# 4  0.933263  0.968981  0.921739

# %% [markdown]
# <h3 Style="color:color:##2F4F4F"> 3.4Binning </h3>

# %%
dfAutos.head(5)
# Out:
#    symboling  normalized    make fuel aspiration doors        style wheels  \
# 0          2         134  toyota  gas        std   two      hardtop    rwd
# 1          2         134  toyota  gas        std   two    hatchback    rwd
# 2          2         134  toyota  gas        std   two      hardtop    rwd
# 3          2         134  toyota  gas        std   two    hatchback    rwd
# 4          2         134  toyota  gas        std   two  convertible    rwd
#
#   engine  base  ...  bore  stroke  compression  horsepower  peak City  Higway  \
# 0  front  98.4  ...  3.62     3.5          9.3         116  4800   24      30
# 1  front  98.4  ...  3.62     3.5          9.3         116  4800   24      30
# 2  front  98.4  ...  3.62     3.5          9.3         116  4800   24      30
# 3  front  98.4  ...  3.62     3.5          9.3         116  4800   24      30
# 4  front  98.4  ...  3.62     3.5          9.3         116  4800   24      30
#
#      price  city-L/100KM  Higway-L/100KM
# ...

# %%
dfAutos[["horsepower"]]=dfAutos[["horsepower"]].astype("int")
dfAutos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 28 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   symboling       58 non-null     int64
#  1   normalized      58 non-null     int32
#  2   make            58 non-null     object
#  3   fuel            58 non-null     object
#  4   aspiration      58 non-null     object
#  5   doors           58 non-null     object
#  6   style           58 non-null     object
#  7   wheels          58 non-null     object
#  8   engine          58 non-null     object
#  9   base            58 non-null     float64
#  10  length          58 non-null     float64
#  11  width           58 non-null     float64
#  12  heingt          58 non-null     float64
#  13  curb            58 non-null     int64
#  14  engineType      58 non-null     object
#  15  Cylinders       58 non-null     object
#  16  engine-size     58 non-null     int64
# ...

# %%
cat=np.linspace(min(dfAutos["horsepower"]),max(dfAutos["horsepower"]),4)
cat
# Out:
# array([ 52.        ,  88.33333333, 124.66666667, 161.        ])

# %%
nombres=["bajo", "medio","alto"]
dfAutos["horsepower-bins"]=pd.cut(dfAutos["horsepower"],bins=cat, labels=nombres, include_lowest=True)
dfAutos[["horsepower","horsepower-bins"]].head(5)
# Out:
#    horsepower horsepower-bins
# 0         116           medio
# 1         116           medio
# 2         116           medio
# 3         116           medio
# 4         116           medio

# %%
dfAutos["horsepower-bins"].value_counts()
# Out:
# medio    32
# bajo     18
# alto      8
# Name: horsepower-bins, dtype: int64

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
plt.hist(dfAutos["horsepower-bins"])
plt.xlabel("Horsepower")
plt.ylabel("Cantidad Autos")
plt.title("Distribucion Autos segun Caballos de fuerza")
plt.show()

# %% [markdown]
# <h2 Style="color:#6294ED">4. Visualizacion de Datos </h2>
# <p>Que se hace en esta etapa?</p>
#
#
# <ol>
#     <li>Verificar el dominio de las variables y se ajusta, si es necesario </li>
#     <li>Responder las preguntas de Negocio </li>
#     <li>Liberar conocimiento</li>
#     <li>Generar informe al Negocio</li>
#
# </ol>

# %%
gf1= dfAutos.groupby(["horsepower-bins"]).count()
gf1=gf1.iloc[:,:1]
gf1
# Out:
#                  symboling
# horsepower-bins
# bajo                    18
# medio                   32
# alto                     8

# %%
eje_x= ("Bajo","Medio","Alto")
eje_y= gf1["symboling"].tolist()
#creamos la grafica 
plt.bar(eje_x, eje_y)
# Leyenda en el eje y
plt.ylabel("Cantidad de Autos")
#leyenda en el eje x
plt.xlabel("Caballos de Fuerza").set_color("#0000FF")
#Titulo del Grafico
plt.title("Autos agrupados por caballos de fuerza")
plt.figure(figsize=(15,20))
plt.show()

# %%
gf2=dfAutos.groupby(["make"]).count()
gf2=gf2.iloc[:,:1]
#gf2t = gf2.sort_values("symboling")#estas 2 lineas ultimas de codigo ordena por cantidad de menor a mayor en caso de activar
#gf2t
gf2
# Out:
#             symboling
# make
# toyota             28
# volkswagen         24
# volvo               6

# %%
eje_x = ("alfa-romero","audi","bmw","chevrolet","dodge","honda","isuzu","jaguar","mazda","Mercedez","Mercury","mitsubishi","nissan","peugot","plymouth","porshe","Saab","subaru","Toyota","Volkswagen","Volvo")
eje_y = gf2["symboling"].tolist()
 
plt.rcdefaults()
fig, ax = plt.subplots()

y_pos=np.arange(len(eje_x))



ax.barh(y_pos, eje_y, align ="center", color= ("#006400")
ax.set_yticks(y_pos, labels=eje_x)
ax.invert_yaxis()
ax.set_xlabel("performance").set_color("#0000FF")
ax.set_title("Cantidad de vehiculos según fabricante")


plt.show()
# Out:
#   Input In [61]
#     ax.set_yticks(y_pos, labels=eje_x)
#     ^
# SyntaxError: invalid syntax

# %%
dfAutos.head(2)

# %%
gf3=dfAutos.groupby(["doors"]).count()
gf3=gf3.iloc[:,:1]
gf3

# %%
etiqueta = "four" , "two"
sizes = gf3["symboling"].tolist()

separacion = (0, 0.1)
figl , axl = plt.subplots()
axl.pie(sizes , explode = separacion, labels=etiqueta, autopct="%1.2f%%", shadow=True, startangle=90)
axl.axis("equal")   
        
plt.show

# %%
gf4=dfAutos.groupby(["style"]).count()
gf4=gf4.iloc[:,:1]
gf4

# %%
fig, ax = plt.subplots(figsize=(8,4), subplot_kw=dict(aspect="equal"))

data=gf4["symboling"].tolist()
estilo=["Convertible","Hardtop","Hatchback","Sedan","Wagon"]

def func(pct, allvals):
    absolute = int(np.round(pct/100.*np.sum(allvals)))
    return "{:.1f}%".format(pct, absolute)

wedges, texts, autotexts = ax.pie(data, autopct=lambda pct: func(pct, data),textprops=dict(color="w"))

ax.legend(wedges, estilo,
          title="Estilo",
          loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1.5))

plt.setp(autotexts, size=6, weight="bold")

ax.set_title("Autos segun estilo")

plt.show()

# %%
gf5=dfAutos.groupby(["style"]).count()
gf5=gf5.iloc[:,:1]
gf5

# %%
fig, ax = plt.subplots(figsize=(0.3), subplot_kw=dict(aspect="equal"))

data=gf4["style"].tolist()
estilo=["Convertible","Hardtop","Hatchback","Sedan","Wagon"]

fig, ax = plt.subplots()

size = 0.3
vals = np.array([[60., 32.], [37., 40.], [29., 10.]])

cmap = plt.colormaps["tab20c"]
outer_colors = cmap(np.arange(3)*4)
inner_colors = cmap([1, 2, 5, 6, 9, 10])

ax.pie(vals.sum(axis=1), radius=1, colors=outer_colors,
       wedgeprops=dict(width=size, edgecolor='w'))

ax.pie(vals.flatten(), radius=1-size, colors=inner_colors,
       wedgeprops=dict(width=size, edgecolor='w'))

ax.set(aspect="equal", title='Pie plot with `ax.pie`')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [62], in <cell line: 1>()
# ----> 1 fig, ax = plt.subplots(figsize=(0.3), subplot_kw=dict(aspect="equal"))
#       3 data=gf4["style"].tolist()
#       4 estilo=["Convertible","Hardtop","Hatchback","Sedan","Wagon"]
#
# File C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py:1434, in subplots(nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw, **fig_kw)
#    1300 def subplots(nrows=1, ncols=1, *, sharex=False, sharey=False, squeeze=True,
#    1301              subplot_kw=None, gridspec_kw=None, **fig_kw):
#    1302     """
#    1303     Create a figure and a set of subplots.
#    1304
#    (...)
#    1432
#    1433     """
# -> 1434     fig = figure(**fig_kw)
#    1435     axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
# ...

# %%
import matplotlib.cbook as cbook



fig, ax = plt.subplots()
ax.scatter(dfAutos['price'], dfAutos['city-L/100KM'],s=dfAutos['horsepower'], alpha=0.4)


ax.set_xlabel("Precio", fontsize=15)
ax.set_ylabel("Consumo litros gasolina en ciudad", fontsize=15)
ax.set_title('Volume and percent change')


ax.grid(True)
fig.tight_layout()


plt.show()
